# %% [markdown]
# # Heirarchical Modelling of the Rugby Premiership

# %%
import pandas as pd
import numpy as np
import pymc3 as pm
import theano.tensor as tt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-3742cbf8727b> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import pymc3 as pm
#       4 import os
#       5 #os.environ["MKL_THREADING_LAYER"] = "GNU"
#
# ~/anaconda3/envs/rugby_conda/lib/python3.5/site-packages/pymc3/__init__.py in <module>()
#      10 from .model import *
#      11 from .model_graph import model_to_graphviz
# ---> 12 from .stats import *
#      13 from .sampling import *
#      14 from .step_methods import *
#
# ~/anaconda3/envs/rugby_conda/lib/python3.5/site-packages/pymc3/stats.py in <module>()
#      12 from pymc3.theanof import floatX
#      13
# ---> 14 from scipy.special import logsumexp
#      15 from scipy.stats import dirichlet
#      16 from scipy.optimize import minimize
#
# ImportError: cannot import name 'logsumexp'

# %% [markdown]
# ## Simple model
# Inspired by [football model by Daniel Weitzenfeld.](http://danielweitzenfeld.github.io/passtheroc/blog/2014/10/28/bayes-premier-league/)
#
# First we need to load the data and restrict our attention to the 2016-2017 season.

# %%
df = pd.read_csv('expected_points/match_results.csv',index_col=0)
df['date'] = pd.to_datetime(df['date'])
# restrict to 2016-2017 season for now
df = df.loc[(df['date'] > '2016-08-01') & (df['date'] <= '2017-08-01')]
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>home_team</th>
#       <th>date</th>
#       <th>away_team</th>
#       <th>home_score</th>
#       <th>away_score</th>
#       <th>away_tries</th>
#       <th>away_pens</th>
#       <th>home_tries</th>
#       <th>home_pens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>457</th>
#       <td>Sale Sharks</td>
#       <td>2016-09-09</td>
#       <td>Harlequins</td>
#       <td>19.0</td>
#       <td>10.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>458</th>
#       <td>Bath Rugby</td>
#       <td>2016-09-10</td>
#       <td>Newcastle Falcons</td>
#       <td>58.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>7.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>459</th>
#       <td>Leicester Tigers</td>
#       <td>2016-09-10</td>
#       <td>Wasps</td>
#       <td>22.0</td>
#       <td>34.0</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>460</th>
#       <td>Bristol Rugby</td>
#       <td>2016-09-11</td>
#       <td>Northampton Saints</td>
#       <td>10.0</td>
#       <td>32.0</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>461</th>
#       <td>Exeter Chiefs</td>
#       <td>2016-09-11</td>
#       <td>Saracens</td>
#       <td>13.0</td>
#       <td>34.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
teams = df.home_team.unique()
teams = pd.DataFrame(teams, columns=['team'])
teams['i'] = teams.index
teams.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>team</th>
#       <th>i</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sale Sharks</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bath Rugby</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Leicester Tigers</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bristol Rugby</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Exeter Chiefs</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Now we'll '

# %%
df = pd.merge(df, teams, left_on='home_team', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_home'}).drop('team', 1)
df = pd.merge(df, teams, left_on='away_team', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_away'}).drop('team', 1)
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>home_team</th>
#       <th>date</th>
#       <th>away_team</th>
#       <th>home_score</th>
#       <th>away_score</th>
#       <th>away_tries</th>
#       <th>away_pens</th>
#       <th>home_tries</th>
#       <th>home_pens</th>
#       <th>i_home</th>
#       <th>i_away</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sale Sharks</td>
#       <td>2016-09-09</td>
#       <td>Harlequins</td>
#       <td>19.0</td>
#       <td>10.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>4.0</td>
#       <td>0</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bath Rugby</td>
#       <td>2016-09-10</td>
#       <td>Newcastle Falcons</td>
#       <td>58.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>7.0</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Leicester Tigers</td>
#       <td>2016-09-10</td>
#       <td>Wasps</td>
#       <td>22.0</td>
#       <td>34.0</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>2</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bristol Rugby</td>
#       <td>2016-09-11</td>
#       <td>Northampton Saints</td>
#       <td>10.0</td>
#       <td>32.0</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Exeter Chiefs</td>
#       <td>2016-09-11</td>
#       <td>Saracens</td>
#       <td>13.0</td>
#       <td>34.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We need to convert the data into array of the same length so that pymc can work with it

# %%
observed_home_score = df.home_score.values
observed_away_score = df.away_score.values
home_team = df.i_home.values
away_team = df.i_away.values
num_teams = len(df.i_home.unique())
num_games = len(home_team)

# %% [markdown]
# Generate some initial values (not necessary)

# %%
g = df.groupby('i_away')
att_starting_points = np.log(g.away_score.mean())
g = df.groupby('i_home')
def_starting_points = -np.log(g.away_score.mean())

# %% [markdown]
# ### Build the model

# %%
with pm.Model() as model:
    # global model parameters
    home = pm.Flat('home') # intercept for home advantage
    sd_att = pm.HalfStudentT('sd_att', nu=3, sigma=2.5)
    sd_def = pm.HalfStudentT('sd_def', nu=3, sigma=2.5)
    intercept = pm.Flat('intercept')

    # team-specific model parameters
    atts_star = pm.Normal("atts_star", mu=0, sigma=sd_att, shape=num_teams)
    defs_star = pm.Normal("defs_star", mu=0, sigma=sd_def, shape=num_teams)

    atts = pm.Deterministic('atts', atts_star - tt.mean(atts_star))
    defs = pm.Deterministic('defs', defs_star - tt.mean(defs_star))
    home_theta = tt.exp(intercept + home + atts[home_team] + defs[away_team])
    away_theta = tt.exp(intercept + atts[away_team] + defs[home_team])

    # likelihood of observed data
    home_points = pm.Poisson('home_points', mu=home_theta, observed=observed_home_score)
    away_points = pm.Poisson('away_points', mu=away_theta, observed=observed_away_score)
# Out:
# /home/michael/anaconda3/lib/python3.6/site-packages/pymc/Model.py:94: UserWarning: The MCMC() syntax is deprecated. Please pass in nodes explicitly via M = MCMC(input).
#   'The MCMC() syntax is deprecated. Please pass in nodes explicitly via M = MCMC(input).')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-fded7d8ebfcf> in <module>()
# ----> 1 with pm.Model() as model:
#       2     # global model parameters
#       3     home = pm.Flat('home') # intercept for home advantage
#       4     sd_att = pm.HalfStudentT('sd_att', nu=3, sigma=2.5)
#       5     sd_def = pm.HalfStudentT('sd_def', nu=3, sigma=2.5)
#
# AttributeError: __enter__
